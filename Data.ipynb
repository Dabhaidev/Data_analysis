# %% [markdown]
# <a href="https://colab.research.google.com/github/Dabhaidev/Data_analysis/blob/main/Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from math import *
sine_wave = [sin(I)*3 for I in range(0,179900,339)]
plt.plot(sine_wave)
plt.show()
